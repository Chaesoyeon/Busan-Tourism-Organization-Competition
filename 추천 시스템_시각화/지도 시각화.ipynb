# %%
import pandas as pd
import folium
from folium import Marker
from folium.plugins import MarkerCluster

# %%
df = pd.read_csv('C:/Users/pc/anaconda3/시장 별 가게 최최최최종본.csv', encoding = 'cp949')
#df = pd.read_csv('D:/Users/ChaeSoYeon/Desktop/지도시각화/시장 별 가게 최최최최종본.csv', encoding = 'cp949')

noncar_target = ['국제시장', '꽃분이네', '아리랑거리', '힙컵', '대정양 곱창']
car_target = ['국제시장', '꽃분이네', '아리랑거리', '대정양 곱창', '부산자갈치시장']

non_car = df[df['가게명'].isin(noncar_target)]

car = df[df['가게명'].isin(car_target)]

# %% [markdown]
# ## 차 없을 때

# %%
map = folium.Map(location = [35.099317, 129.029629], tiles = 'OpenStreetMap', zoom_start = 15.5)

# 거점 - 현재위치
folium.CircleMarker([35.098943,129.024825],
                   radius = 150,
                    color = 'green',
                   fill_color = 'green').add_to(map)
folium.Marker([35.098943,129.024825],
             popup = '<pre>' + '현재 위치: 서구청 버스정류장 ' + '<br>' + '</pre>',
             icon = folium.Icon(color = 'green', icon = 'user')).add_to(map)

# 거점 - 여행지1
folium.CircleMarker([35.101387, 129.028765],
                   radius = 150,
                    color = 'orange',
                   fill_color = 'orange').add_to(map)
folium.Marker([35.101387, 129.028765],
             popup = '<pre>' + '여행지1: 국제시장 ' + '<br>' + '</pre>',
             icon = folium.Icon(color = 'orange', icon = 'bookmark')).add_to(map)

# 거점 - 여행지2
folium.CircleMarker([35.096948,129.030169],
                   radius = 150,
                    color = 'orange',
                   fill_color = 'orange').add_to(map)
folium.Marker([35.096948,129.030169],
             popup = '<pre>' + '여행지2: 자갈치시장 ' + '<br>' + '</pre>',
             icon = folium.Icon(color = 'orange', icon = 'bookmark')).add_to(map)

# 거점 - 도착지
folium.CircleMarker([35.099297,129.032557],
                   radius = 150,
                    color = 'darkblue',
                   fill_color = 'skyblue').add_to(map)
folium.Marker([35.099297,129.032557],
             popup = '<pre>' + '도착지: 마론호텔 ' + '<br>' + '</pre>',
             icon = folium.Icon(color = 'darkblue', icon = 'home')).add_to(map)

# 추천장소
for _, i in non_car.iterrows():
    Marker(location = [i['가게 위치(위도)'], i['가게 위치(경도)']],
          popup = '<pre>' + '가게명: ' + str(i['가게명']) + '<br>' + '</pre>',
          icon = folium.Icon(color = 'gray', icon = 'star')). add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
noncar_target_2 = ['국제시장', '꽃분이네', '아리랑거리', '힙컵', '돌솥밥집']

non_car_2 = df[df['가게명'].isin(noncar_target_2)]

# %%
map = folium.Map(location = [35.099317, 129.029629], tiles = 'OpenStreetMap', zoom_start = 15.5)

# 거점 - 현재위치
folium.CircleMarker([35.100036,129.026109],
                   radius = 150,
                    color = 'green',
                   fill_color = 'green').add_to(map)
folium.Marker([35.100036,129.026109],
             popup = '<pre>' + '현재 위치: 대정 양곱창 ' + '<br>' + '</pre>',
             icon = folium.Icon(color = 'green', icon = 'user')).add_to(map)

# 거점 - 여행지1
folium.CircleMarker([35.101387, 129.028765],
                   radius = 150,
                    color = 'orange',
                   fill_color = 'orange').add_to(map)
folium.Marker([35.101387, 129.028765],
             popup = '<pre>' + '여행지1: 국제시장 ' + '<br>' + '</pre>',
             icon = folium.Icon(color = 'orange', icon = 'bookmark')).add_to(map)

# 거점 - 여행지2
folium.CircleMarker([35.096948,129.030169],
                   radius = 150,
                    color = 'orange',
                   fill_color = 'orange').add_to(map)
folium.Marker([35.096948,129.030169],
             popup = '<pre>' + '여행지2: 자갈치시장 ' + '<br>' + '</pre>',
             icon = folium.Icon(color = 'orange', icon = 'bookmark')).add_to(map)

# 거점 - 도착지
folium.CircleMarker([35.099297,129.032557],
                   radius = 150,
                    color = 'darkblue',
                   fill_color = 'skyblue').add_to(map)
folium.Marker([35.099297,129.032557],
             popup = '<pre>' + '도착지: 마론호텔 ' + '<br>' + '</pre>',
             icon = folium.Icon(color = 'darkblue', icon = 'home')).add_to(map)

# 추천장소
for _, i in non_car_2.iterrows():
    Marker(location = [i['가게 위치(위도)'], i['가게 위치(경도)']],
          popup = '<pre>' + '가게명: ' + str(i['가게명']) + '<br>' + '</pre>',
          icon = folium.Icon(color = 'gray', icon = 'star')). add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
noncar_target_3 = ['국제시장', '부산자갈치시장', '승기씨앗호떡', '카마타케제면소 본점', '꽃분이네']

non_car_3 = df[df['가게명'].isin(noncar_target_3)]

# %%
map = folium.Map(location = [35.099317, 129.029629], tiles = 'OpenStreetMap', zoom_start = 15.5)

# 거점 - 현재 위치
folium.CircleMarker([35.101387, 129.028765],
                   radius = 150,
                    color = 'green',
                   fill_color = 'green').add_to(map)
folium.Marker([35.101387, 129.028765],
             popup = '<pre>' + '현재 위치: 국제시장 ' + '<br>' + '</pre>',
             icon = folium.Icon(color = 'green', icon = 'user')).add_to(map)

# 거점 - 여행지2
folium.CircleMarker([35.096948,129.030169],
                   radius = 150,
                    color = 'orange',
                   fill_color = 'orange').add_to(map)
folium.Marker([35.096948,129.030169],
             popup = '<pre>' + '여행지2: 자갈치시장 ' + '<br>' + '</pre>',
             icon = folium.Icon(color = 'orange', icon = 'bookmark')).add_to(map)

# 거점 - 도착지
folium.CircleMarker([35.099297,129.032557],
                   radius = 150,
                    color = 'darkblue',
                   fill_color = 'skyblue').add_to(map)
folium.Marker([35.099297,129.032557],
             popup = '<pre>' + '도착지: 마론호텔 ' + '<br>' + '</pre>',
             icon = folium.Icon(color = 'darkblue', icon = 'home')).add_to(map)

# 추천장소
for _, i in non_car_3.iterrows():
    Marker(location = [i['가게 위치(위도)'], i['가게 위치(경도)']],
          popup = '<pre>' + '가게명: ' + str(i['가게명']) + '<br>' + '</pre>',
          icon = folium.Icon(color = 'gray', icon = 'star')). add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
noncar_target_4 = ['부산명물횟집', '개미집']

non_car_4 = df[df['가게명'].isin(noncar_target_4)]

# %%
map = folium.Map(location = [35.099317, 129.029629], tiles = 'OpenStreetMap', zoom_start = 15.5)

# 거점 - 현재위치
folium.CircleMarker([35.096948,129.030169],
                   radius = 150,
                    color = 'green',
                   fill_color = 'green').add_to(map)
folium.Marker([35.096948,129.030169],
             popup = '<pre>' + '여행지2: 자갈치시장 ' + '<br>' + '</pre>',
             icon = folium.Icon(color = 'green', icon = 'user')).add_to(map)

# 거점 - 도착지
folium.CircleMarker([35.099297,129.032557],
                   radius = 150,
                    color = 'darkblue',
                   fill_color = 'skyblue').add_to(map)
folium.Marker([35.099297,129.032557],
             popup = '<pre>' + '도착지: 마론호텔 ' + '<br>' + '</pre>',
             icon = folium.Icon(color = 'darkblue', icon = 'home')).add_to(map)

# 추천장소
for _, i in non_car_4.iterrows():
    Marker(location = [i['가게 위치(위도)'], i['가게 위치(경도)']],
          popup = '<pre>' + '가게명: ' + str(i['가게명']) + '<br>' + '</pre>',
          icon = folium.Icon(color = 'gray', icon = 'star')). add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# ## 차 있을 때

# %%
map = folium.Map(location = [35.099317, 129.029629], tiles = 'OpenStreetMap', zoom_start = 15.5)

# 거점 - 현재위치
folium.CircleMarker([35.098943,129.024825],
                   radius = 150,
                    color = 'green',
                   fill_color = 'green').add_to(map)
folium.Marker([35.098943,129.024825],
             popup = '<pre>' + '현재 위치: 서구청 버스정류장 ' + '<br>' + '</pre>',
             icon = folium.Icon(color = 'green', icon = 'user')).add_to(map)

# 거점 - 여행지1
folium.CircleMarker([35.101387, 129.028765],
                   radius = 150,
                    color = 'orange',
                   fill_color = 'orange').add_to(map)
folium.Marker([35.101387, 129.028765],
             popup = '<pre>' + '여행지1: 국제시장 ' + '<br>' + '</pre>',
             icon = folium.Icon(color = 'orange', icon = 'bookmark')).add_to(map)

# 거점 - 여행지2
folium.CircleMarker([35.096948,129.030169],
                   radius = 150,
                    color = 'orange',
                   fill_color = 'orange').add_to(map)
folium.Marker([35.096948,129.030169],
             popup = '<pre>' + '여행지2: 자갈치시장 ' + '<br>' + '</pre>',
             icon = folium.Icon(color = 'orange', icon = 'bookmark')).add_to(map)

# 거점 - 도착지
folium.CircleMarker([35.099297,129.032557],
                   radius = 150,
                    color = 'darkblue',
                   fill_color = 'skyblue').add_to(map)
folium.Marker([35.099297,129.032557],
             popup = '<pre>' + '도착지: 마론호텔 ' + '<br>' + '</pre>',
             icon = folium.Icon(color = 'darkblue', icon = 'home')).add_to(map)

# 추천장소
for _, i in car.iterrows():
    Marker(location = [i['가게 위치(위도)'], i['가게 위치(경도)']],
          popup = '<pre>' + '가게명: ' + str(i['가게명']) + '<br>' + '</pre>',
          icon = folium.Icon(color = 'gray', icon = 'star')). add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
car_target_2 = ['국제시장', '꽃분이네', '아리랑거리', '돌솥밥집', '카마타케제면소 본점']
car_2 = df[df['가게명'].isin(car_target_2)]

# %%
map = folium.Map(location = [35.099317, 129.029629], tiles = 'OpenStreetMap', zoom_start = 15.5)

# 거점 - 현재위치
folium.CircleMarker([35.100036,129.026109],
                   radius = 150,
                    color = 'green',
                   fill_color = 'green').add_to(map)
folium.Marker([35.100036,129.026109],
             popup = '<pre>' + '현재 위치: 대정 양곱창 ' + '<br>' + '</pre>',
             icon = folium.Icon(color = 'green', icon = 'user')).add_to(map)

# 거점 - 여행지1
folium.CircleMarker([35.101387, 129.028765],
                   radius = 150,
                    color = 'orange',
                   fill_color = 'orange').add_to(map)
folium.Marker([35.101387, 129.028765],
             popup = '<pre>' + '여행지1: 국제시장 ' + '<br>' + '</pre>',
             icon = folium.Icon(color = 'orange', icon = 'bookmark')).add_to(map)

# 거점 - 여행지2
folium.CircleMarker([35.096948,129.030169],
                   radius = 150,
                    color = 'orange',
                   fill_color = 'orange').add_to(map)
folium.Marker([35.096948,129.030169],
             popup = '<pre>' + '여행지2: 자갈치시장 ' + '<br>' + '</pre>',
             icon = folium.Icon(color = 'orange', icon = 'bookmark')).add_to(map)

# 거점 - 도착지
folium.CircleMarker([35.099297,129.032557],
                   radius = 150,
                    color = 'darkblue',
                   fill_color = 'skyblue').add_to(map)
folium.Marker([35.099297,129.032557],
             popup = '<pre>' + '도착지: 마론호텔 ' + '<br>' + '</pre>',
             icon = folium.Icon(color = 'darkblue', icon = 'home')).add_to(map)

# 추천장소
for _, i in car_2.iterrows():
    Marker(location = [i['가게 위치(위도)'], i['가게 위치(경도)']],
          popup = '<pre>' + '가게명: ' + str(i['가게명']) + '<br>' + '</pre>',
          icon = folium.Icon(color = 'gray', icon = 'star')). add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
car_target_3 = ['국제시장', '부산자갈치시장', '승기씨앗호떡', '카마타케제면소 본점', '꽃분이네']
car_3 = df[df['가게명'].isin(car_target_3)]

# %%
map = folium.Map(location = [35.099317, 129.029629], tiles = 'OpenStreetMap', zoom_start = 15.5)

# 거점 - 현재위치
folium.CircleMarker([35.101387, 129.028765],
                   radius = 150,
                    color = 'green',
                   fill_color = 'green').add_to(map)
folium.Marker([35.101387, 129.028765],
             popup = '<pre>' + '여행지1: 국제시장 ' + '<br>' + '</pre>',
             icon = folium.Icon(color = 'green', icon = 'user')).add_to(map)

# 거점 - 여행지2
folium.CircleMarker([35.096948,129.030169],
                   radius = 150,
                    color = 'orange',
                   fill_color = 'orange').add_to(map)
folium.Marker([35.096948,129.030169],
             popup = '<pre>' + '여행지2: 자갈치시장 ' + '<br>' + '</pre>',
             icon = folium.Icon(color = 'orange', icon = 'bookmark')).add_to(map)

# 거점 - 도착지
folium.CircleMarker([35.099297,129.032557],
                   radius = 150,
                    color = 'darkblue',
                   fill_color = 'skyblue').add_to(map)
folium.Marker([35.099297,129.032557],
             popup = '<pre>' + '도착지: 마론호텔 ' + '<br>' + '</pre>',
             icon = folium.Icon(color = 'darkblue', icon = 'home')).add_to(map)

# 추천장소
for _, i in car_3.iterrows():
    Marker(location = [i['가게 위치(위도)'], i['가게 위치(경도)']],
          popup = '<pre>' + '가게명: ' + str(i['가게명']) + '<br>' + '</pre>',
          icon = folium.Icon(color = 'gray', icon = 'star')). add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
car_target_4 = ['부산명물횟집', '개미집']
car_4 = df[df['가게명'].isin(car_target_4)]

# %%
map = folium.Map(location = [35.099317, 129.029629], tiles = 'OpenStreetMap', zoom_start = 15.5)

# 거점 - 여행지2
folium.CircleMarker([35.096948,129.030169],
                   radius = 150,
                    color = 'green',
                   fill_color = 'green').add_to(map)
folium.Marker([35.096948,129.030169],
             popup = '<pre>' + '여행지2: 자갈치시장 ' + '<br>' + '</pre>',
             icon = folium.Icon(color = 'green', icon = 'user')).add_to(map)

# 거점 - 도착지
folium.CircleMarker([35.099297,129.032557],
                   radius = 150,
                    color = 'darkblue',
                   fill_color = 'skyblue').add_to(map)
folium.Marker([35.099297,129.032557],
             popup = '<pre>' + '도착지: 마론호텔 ' + '<br>' + '</pre>',
             icon = folium.Icon(color = 'darkblue', icon = 'home')).add_to(map)

# 추천장소
for _, i in car_4.iterrows():
    Marker(location = [i['가게 위치(위도)'], i['가게 위치(경도)']],
          popup = '<pre>' + '가게명: ' + str(i['가게명']) + '<br>' + '</pre>',
          icon = folium.Icon(color = 'gray', icon = 'star')). add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# ## 시각화 - 전통시장개수

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
area = ['서울', '부산', '대구', '인천', '광주', '대전', '울산', '경기', '강원', '충북', '충남', '전북', '전남', '경북', '경남', '제주', '세종']
market = [209, 168, 101, 44, 24, 28, 39, 142, 59, 57, 58, 58, 93, 138, 157, 22, 4]

mk = pd.DataFrame()
mk['area'] = area
mk['market'] = market

mk = mk.sort_values('market')
mk
# Out:
#    area  market
# 16   세종       4
# 15   제주      22
# 4    광주      24
# 5    대전      28
# 6    울산      39
# 3    인천      44
# 9    충북      57
# 11   전북      58
# 10   충남      58
# 8    강원      59
# 12   전남      93
# 2    대구     101
# 13   경북     138
# 7    경기     142
# 14   경남     157
# 1    부산     168
# 0    서울     209

# %%
index = range(len(mk['area']))

barh = plt.barh(index, mk['market'],
                color = ['grey', 'grey', 'grey', 'grey', 'grey', 'grey', 'grey', 'grey', 'grey', 'grey', 'grey', 'grey', 'grey', 'grey', 'grey', 'red', 'grey'])

plt.yticks(index, mk['area'])

for idx, value in enumerate(mk['market']):
    plt.text(value, idx, str(value))

plt.show()
# Out:
# C:\Users\pc\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 49464 (\N{HANGUL SYLLABLE SE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\pc\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 51333 (\N{HANGUL SYLLABLE JONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\pc\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 51228 (\N{HANGUL SYLLABLE JE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\pc\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 51452 (\N{HANGUL SYLLABLE JU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\pc\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 44305 (\N{HANGUL SYLLABLE GWANG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %% [markdown]
# ## 전국 시각화

# %%
# 전통 시장 수
# 점포상인
# 빈점포

import geopandas as gpd
import json

# %%
area = ['서울', '부산', '대구', '인천', '광주', '대전', '울산', '경기', '강원', '충북', '충남', '전북', '전남', '경북', '경남', '제주', '세종']
maket = [206, 166, 100, 44, 24, 28, 40, 148, 62, 57, 58, 58, 95, 137, 158, 23,4]
no_sale = [4180,3851,3436,384,210,213,342,1410,697,518,530,465,561,2186,2817,208,34]
saler = [40810,23541,14118,10725,2880,2734,3728,19112,6747,6088,6597,4246,6353,14545,15103,3701,546]

korea = pd.DataFrame()
korea['행정구역'] = area
korea['전통시장 수'] = market
korea['빈점포 수'] = no_sale
korea['점포상인 수'] = saler

# %%
korea
# Out:
#    행정구역  전통시장 수  빈점포 수  점포상인 수
# 0    서울     209   4180   40810
# 1    부산     168   3851   23541
# 2    대구     101   3436   14118
# 3    인천      44    384   10725
# 4    광주      24    210    2880
# 5    대전      28    213    2734
# 6    울산      39    342    3728
# 7    경기     142   1410   19112
# 8    강원      59    697    6747
# 9    충북      57    518    6088
# 10   충남      58    530    6597
# 11   전북      58    465    4246
# 12   전남      93    561    6353
# 13   경북     138   2186   14545
# 14   경남     157   2817   15103
# 15   제주      22    208    3701
# 16   세종       4     34     546

# %%
# 파일읽기
kr_file = gpd.read_file('C:/Users/pc/Downloads/CTPRVN_20221119/ctp_rvn.shp', encoding = 'cp949')
#kr_file = gpd.read_file('D:/Users/ChaeSoYeon/Desktop/지도시각화/CTPRVN_20221119/ctp_rvn.shp', encoding = 'cp949')

# %%
# '서울', '부산', '대구', '인천', '광주', '대전', '울산', '경기', '강원', '충북', '충남', '전북', '전남', '경북', '경남', '제주', '세종'
kr = kr_file.reindex(index = [0,1,2,3,4,5,6,8,9,10,11,12,13,14,15,16,7])
kr = kr.reset_index(drop = True)
kr
# Out:
#    CTPRVN_CD         CTP_ENG_NM CTP_KOR_NM  \
# 0         11              Seoul      서울특별시
# 1         26              Busan      부산광역시
# 2         27              Daegu      대구광역시
# 3         28            Incheon      인천광역시
# 4         29            Gwangju      광주광역시
# 5         30            Daejeon      대전광역시
# 6         31              Ulsan      울산광역시
# 7         41        Gyeonggi-do        경기도
# 8         42         Gangwon-do        강원도
# 9         43  Chungcheongbuk-do       충청북도
# 10        44  Chungcheongnam-do       충청남도
# 11        45       Jeollabuk-do       전라북도
# 12        46        Jellanam-do       전라남도
# 13        47   Gyeongsangbuk-do       경상북도
# 14        48   Gyeongsangnam-do       경상남도
# 15        50            Jeju-do    제주특별자치도
# 16        36          Sejong-si    세종특별자치시
#
#                                              geometry
# 0   POLYGON ((966987.226 1941110.946, 966987.119 1...
# 1   MULTIPOLYGON (((1148194.981 1685460.055, 11481...
# ...

# %%
result = pd.concat([kr, korea], axis = 1)
result
# Out:
#    CTPRVN_CD         CTP_ENG_NM CTP_KOR_NM  \
# 0         11              Seoul      서울특별시
# 1         26              Busan      부산광역시
# 2         27              Daegu      대구광역시
# 3         28            Incheon      인천광역시
# 4         29            Gwangju      광주광역시
# 5         30            Daejeon      대전광역시
# 6         31              Ulsan      울산광역시
# 7         41        Gyeonggi-do        경기도
# 8         42         Gangwon-do        강원도
# 9         43  Chungcheongbuk-do       충청북도
# 10        44  Chungcheongnam-do       충청남도
# 11        45       Jeollabuk-do       전라북도
# 12        46        Jellanam-do       전라남도
# 13        47   Gyeongsangbuk-do       경상북도
# 14        48   Gyeongsangnam-do       경상남도
# 15        50            Jeju-do    제주특별자치도
# 16        36          Sejong-si    세종특별자치시
#
#                                              geometry 행정구역  전통시장 수  빈점포 수  \
# 0   POLYGON ((966987.226 1941110.946, 966987.119 1...   서울     209   4180
# ...

# %%
result.drop(columns = {'CTP_ENG_NM', 'CTP_KOR_NM'}, inplace = True)
result
# Out:
#    CTPRVN_CD                                           geometry 행정구역  전통시장 수  \
# 0         11  POLYGON ((966987.226 1941110.946, 966987.119 1...   서울     209
# 1         26  MULTIPOLYGON (((1148194.981 1685460.055, 11481...   부산     168
# 2         27  POLYGON ((1087859.999 1760097.461, 1087859.951...   대구     101
# 3         28  MULTIPOLYGON (((847834.755 1881816.658, 847840...   인천      44
# 4         29  POLYGON ((932712.687 1696168.692, 932781.680 1...   광주      24
# 5         30  POLYGON ((990946.725 1832389.260, 991057.692 1...   대전      28
# 6         31  MULTIPOLYGON (((1167949.952 1710285.043, 11679...   울산      39
# 7         41  MULTIPOLYGON (((931607.470 1894480.382, 931653...   경기     142
# 8         42  MULTIPOLYGON (((1163759.191 1909653.101, 11637...   강원      59
# 9         43  POLYGON ((1042689.435 1917662.690, 1042731.339...   충북      57
# 10        44  MULTIPOLYGON (((862386.074 1805282.887, 862296...   충남      58
# ...

# %%
fig, ax = plt.subplots(ncols = 3, sharey = True, figsize = (25,15))
result.plot(ax=ax[0], column = '전통시장 수', cmap = 'viridis', legend = False, alpha = 0.9)
result.plot(ax=ax[1], column = '빈점포 수', cmap = 'viridis', legend = False, alpha = 0.9)
result.plot(ax=ax[2], column = '점포상인 수', cmap = 'viridis', legend = False, alpha = 0.9)
patch_col = ax[0].collections[0]
cb = fig.colorbar(patch_col, ax=ax, shrink = 0.5)
ax[0].set_title('전통시장 수')
ax[1].set_title('빈점포 수')
ax[2].set_title('점포상인 수')
ax[0].set_axis_off();
ax[1].set_axis_off();
ax[2].set_axis_off()
# Out:
# C:\Users\pc\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 51204 (\N{HANGUL SYLLABLE JEON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\pc\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 53685 (\N{HANGUL SYLLABLE TONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\pc\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 49884 (\N{HANGUL SYLLABLE SI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\pc\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 51109 (\N{HANGUL SYLLABLE JANG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\pc\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 49688 (\N{HANGUL SYLLABLE SU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %% [markdown]
# # 부산 클러스터링 시각화

# %%
# 파일읽기
bs_file = gpd.read_file('C:/Users/pc/Downloads/LSMD_ADM_SECT_UMD_부산/LSMD_ADM_SECT_UMD_26.shp', encoding = 'cp949') 
#bs_file = gpd.read_file('D:/Users/ChaeSoYeon/Desktop/지도시각화/LSMD_ADM_SECT_UMD_부산/LSMD_ADM_SECT_UMD_26.shp', encoding = 'cp949')

# %%
bs_file.rename(columns = {'EMD_NM' : '행정동'}, inplace = True)
#bs = bs_file[['행정동', 'geometry']].set_index('행정동')
bs = bs_file[['행정동', 'geometry']]

# %% [markdown]
# ## 클러스터 0 시각화

# %%
#clust_me4 = pd.read_csv('D:/Users/ChaeSoYeon/Desktop/부산공모전 준비/standard_final.csv', encoding = 'cp949')
#clust_me4.columns

# %%
clust_me4 = clust_me4[['시장명', 'k_medoids_4']]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11204\4170548732.py in <module>
# ----> 1 clust_me4 = clust_me4[['시장명', 'k_medoids_4']]
#
# NameError: name 'clust_me4' is not defined

# %%
clust_me4['행정동'] = ['남포동4가', '동광동1가', '신창동4가', '창선동2가', '보수동3가', '남포동6가', '남포동5가', '남포동6가', '부평동2가', '남포동1가',
                   '영주동', '창선동2가', '부평동2가', '신창동3가', '남포동4가', '신창동1가', '보수동1가', '대청동3가', '범일동', '범일동', '범일동',
                   '수정동', '초량동', '수정동', '초량동', '범일동', '범일동', '수정4동', '범천1동', '부전동', '부전동', '부전동', '개금동', '초읍동',
                   '초읍동', '부전동', '당감동', '전포동', '부전동', '가야동', '양정동', '당감동', '부전동', '부전동', '범천1동', '당감동', '개금동',
                   '전포동', '당감동', '부암동', '연지동', '양정동', '부전동', '범천동']

# %%
bs['행정동']
# Out:
# 0      남항동1가
# 1      대평동2가
# 2      대평동1가
# 3      대교동2가
# 4      대교동1가
#        ...
# 192    남항동3가
# 193    남항동2가
# 194      천성동
# 195      초량동
# 196     남부민동
# Name: 행정동, Length: 197, dtype: object

# %%
clust_0 = pd.DataFrame({'행정동' : bs['행정동']})
clust_0['cluster'] = 0

clust0_list = ['신창동4가', '부평동2가', '남포동4가', '신창동1가', '범일동', '부전동', '개금동', '양정동']
clust_0.loc[clust_0['행정동'].isin(clust0_list), 'cluster'] = 1

#clust_0 = clust_0.set_index(keys = ['행정동'], inplace = False, drop = True)

# %%
clust_0
# Out:
#        cluster
# 행정동
# 남항동1가        0
# 대평동2가        0
# 대평동1가        0
# 대교동2가        0
# 대교동1가        0
# ...        ...
# 남항동3가        0
# 남항동2가        0
# 천성동          0
# 초량동          0
# 남부민동         0
#
# [197 rows x 1 columns]

# %%
clust_0.to_csv('C:/Users/pc/Downloads/LSMD_ADM_SECT_UMD_부산/클러스터0.csv', encoding = 'cp949')

# %% [markdown]
# ## 클러스터 1 시각화_전처리

# %%
clust1 = pd.read_csv('C:/Users/pc/Documents/카카오톡 받은 파일/1번 클러스터.csv', encoding = 'cp949')
clust1
# Out:
#      X  개설년도  운영중인.점포.계...빈점포.  매장면적...  종사자.수.명.  주차.면수  용도지역_일반상업  \
# 0    3  1948               144  3892.00       442      0          1
# 1    6  1987               385  7652.28       258    130          1
# 2    8  1995               215  9584.00       145    108          1
# 3   10  1950                64  5597.00       160      0          1
# 4   21  1979                51   231.00        68     23          1
# 5   22  1975                40  3292.00        40      0          1
# 6   26  1970                78  2757.00       100      0          0
# 7   27  1970                44  2813.00        44      0          0
# 8   28  1970               900  6327.00       710    173          1
# 9   32  1978                28   450.00        48      0          0
# 10  37  1981               262  4545.00       140     62          1
# 11  40  1971                73  7445.00       133     66          1
# 12  41  1995                90  3169.00       135     40          0
# ...
